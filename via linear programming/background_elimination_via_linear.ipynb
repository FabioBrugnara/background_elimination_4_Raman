# %% [markdown]
# # A background elimination method based on linear programming for Raman spectra
#
# In this notebook we are trying to reproduce the background elimination technique described in the article of Sung-June Baek, Aaron Park, Aigou Shen, Jiming Hu: https://doi.org/10.1016/j.chemolab.2009.04.007.

# %% [markdown]
# ### Settings and functions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter
from scipy.optimize import linprog
# %matplotlib inline
font = {'size': 15}

# %%
def raman_plot():
    """
    Funzione che serve per settare la dimensione dell'immgine e i label degli assi per un plot di spettro Raman.
    """
    plt.figure(figsize=(16,6))
    plt.xlabel(r"Raman shift [$cm^{-1}$]",fontsize=18)
    plt.ylabel("Intensity [a.u.]",fontsize=18)

# %%
def define_names(r=11,c=11):
    """
    Funzione che definisce i nomi delle coordinate degli spettri sul sample. I nomi sono del tipo r1c1,r1c2, ecc.
    Come default usa 11 colonne e 11 righe. Il primo nome è wn, che sta per wave number.
    """
    #definisco i nomi da assegnare ai punti delli spettri di sampling
    #wn -> wave number  r -> row c -> columns
    names = ['wn']+[f'r{k}c{i}' for k in range(1,r+1) for i in range(1,c+1)]
    return names

# %%
def interpol(S):
    min = int(S[0][0]) if S[0][0]==0 else int(S[0][0]) +1
    max = int(S[0][-1])
    X = np.arange(min,max+1,1)
    S = np.array([X, np.interp(X,S[0],S[1])])
    return S

# %%
def _raman_labels():
    plt.figure(figsize=(10,5))
    plt.xlabel(r'Raman shift [$cm^{-1}$]')
    plt.ylabel('Counts')

def plot(S):
    S = type2spectra(S)
    _raman_labels()
    if type(S)!=list:
        plt.plot(S[0], S[1])
    else:
        for s in S:
            plt.plot(s[0], s[1], label='')
    plt.show(block=False)

# %% [markdown]
# ## Import of some test spectra
# Here we import a few spectra on which to test this background-elimination technique. Then we chose one among these in the variable *col* on which the procedure is performed, change that variable to change the test-spectrum.

# %%
#definisco i nomi delle colonne da dare 
names=define_names()
#quì importiamo i dati dei sampling in dataframes pandas, la colonna dei numeri d'onda è una unica per tutti
data = pd.read_csv('./data/S1_mapA_11x11.txt', delim_whitespace=True, names=names)

# %% [markdown]
# # The procedure

# %% [markdown]
# The first step is the spectrum interpolation. This is something we do for each used spectrum just for simplicity. As can be seen from the plot there is absolutely no differences in the shape of the original spectrum and the interpolated one.

# %%
col= 'r5c7'  #'r5c2'
S =np.array(data[['wn',col]].copy()).transpose()
S=S[:,0:1200]
#S=S[:,1300:]
raman_plot()
plt.plot(S[0],S[1], label = 'original')
S=interpol(S)
plt.plot(S[0],S[1], label = 'interpolated')
plt.title('Spectrum on which to test the analysis',fontsize=18,fontweight='bold')
plt.legend()

# %% [markdown]
# ## Noise removal
# Apply Savitzky–Golay ﬁlter with span $L_n$ to the given spectrum. The degree of a polynomial is set to 2. In the following, $s$ denotes the noise removed data. It doesn't matter if the peaks are distorted since we are interested in the background.

# %%
#############################################################################################
L_n=51                                       #lenght of smoothing filter for noise removal  #
pol_degree=2                                                                                 #
#############################################################################################
S_smooth = S.copy()
S_smooth[1]=savgol_filter(S[1],L_n,pol_degree)

plt.figure(figsize=(16,6))
plt.xlabel("sample",fontsize=18)
plt.ylabel("Intensity [some unit]",fontsize=18)
plt.title('Noise-removed spectrum via Savitzky–Golay filter with span $L_n$ and a second order pol',fontsize=18,fontweight='bold')
plt.plot(S[0],S[1], label='original signal')
plt.plot(S_smooth[0],S_smooth[1], label='smoothed signal')
plt.legend()

# %% [markdown]
# # Polynomial fitting with constrains => Linear programming
# 1. devo mantenere lo spettro non troppo largo, altrimenti numericamente non si riesce a trovare una soluzione!

# %%
p= 11   # polinomial order
edge_width = 20 # this is for the edge problem of polinomial fitting
edge_weight = 2

#############################################################
# vector/matrice Y and X
Y = S_smooth[1]
x = S_smooth[0]
x = (x-x[0])/(x[-1]-x[0])
X = np.zeros((len(x),p))
for i in range(p):
   X[:, i] = x**i

# vector C
H = np.concatenate((np.ones(edge_width)*edge_weight, np.ones(X.shape[0]-2*edge_width), np.ones(edge_width)*edge_weight))
C = - np.dot(H,X)

# solving the linear programming problem
res = linprog(C, A_ub=X, b_ub = Y, bounds = (None, None), method='highs-ds')
W = res['x']
print('sum(Y-XW) = ', res['fun'])
print('status = ', res['status'])
print('message = ', res['message'])
print('# of iter = ', res['nit'])

# generate the BKG
x = S[0]
x = (x-x[0])/(x[-1]-x[0])
X = np.zeros((len(x),p))
for i in range(p):
   X[:, i] = x**i
BKG = np.dot(X,W)
raman_plot()
plt.plot(S[0], BKG)
plt.plot(S[0],S[1])
plt.plot(S_smooth[0],S_smooth[1])


raman_plot()
plt.plot(S[0],S[1]-BKG)
# Out:
# sum(Y-XW) =  -510878.4068417549
# status =  0
# message =  Optimization terminated successfully.
# # of iter =  82

# %% [markdown]
# ## We have to perform this on different sections of the spectra

# %%
S=S # SIGNAL
# 1) the signal must be already smoothed!
# 2) the signal must not be too large!

p= 11   # polinomial order
edge_width = 10 # this is for the edge problem of polinomial fitting
edge_weight = 2

#############################################################
def bkg_fit(S, p, edge_width=20, edge_weight=2, plot=False, verbose=False):
    # vector/matrice Y and X
    Y = S[1]
    x = S[0]
    x = (x-x[0])/(x[-1]-x[0])
    X = np.zeros((len(x),p))
    for i in range(p):
        X[:, i] = x**i

    # vector C
    H = np.concatenate((np.ones(edge_width)*edge_weight, np.ones(X.shape[0]-2*edge_width), np.ones(edge_width)*edge_weight))
    C = - np.dot(H,X)

    # solving the linear programming problem
    res = linprog(C, A_ub=X, b_ub = Y, bounds = (None, None), method='highs-ds')
    W = res['x']
    stat = res['status']
    if verbose == True:
        print('sum(Y-XW) = ', res['fun'])
        print('status = ', res['status'])
        print('message = ', res['message'])
        print('# of iter = ', res['nit'])

    if stat==0:    
        # generate the BKG
        x = S[0]
        x = (x-x[0])/(x[-1]-x[0])
        X = np.zeros((len(x),p))
        for i in range(p):
            X[:, i] = x**i
        BKG = np.dot(X,W)

        if plot==True:
            raman_plot()
            plt.plot(S[0], BKG, label='Estimated background')
            plt.plot(S[0],S[1], label='Original signal')
    
        return np.array([S[0],BKG]), stat
    else:
        return 0, stat

# example: BKG, stat = bkg_fit(S_smooth, 11, edge_width=20, edge_weight=2, plot=True)

def bkg_full_fit(S, p=11, edge_width=20, edge_weight=2, L_n=41, plot=False):
    # SMOOTHING
    S_smooth = S.copy()
    S_smooth[1]=savgol_filter(S[1],L_n,2)

    if plot==True:
        plt.figure(figsize=(16,6))
        plt.xlabel("sample",fontsize=18)
        plt.ylabel("Intensity [some unit]",fontsize=18)
        plt.plot(S[0],S[1], label='Original signal')
        plt.plot(S_smooth[0],S_smooth[1], label='Smoothed signal')
    
    # SEGMENTED FIT
    length = S_smooth.shape[1]
    bounds = []
    i=0
    while i<length:
        if i+1100<=length:
            i+=1100
            bounds.append([i-1100,i])
            i-=200
        else:
            i+=1100  
            bounds.append([length-1100,length])
    
    BKG=[]
    for i in bounds:
        BKG_temp, stat = bkg_fit(S_smooth[:,i[0]:i[1]], p, edge_width, edge_weight)
        if stat != 0:
            print('Fit do not converged, try smaller p!')
            return
        BKG.append(BKG_temp)

    if plot==True:
        #raman_plot()
        for i in BKG:
            plt.plot(i[0], i[1])
        plt.plot(S[0],S[1])

    #L'UNIONE SI PUO RIFARE SICURAMENTE IN MODO PIU PULITO
    BKG_final=BKG[0][:,0:1100-edge_width]
    for i in BKG[1:-1]:
        BKG_final = np.append(BKG_final,i[:,edge_width:-edge_width],axis=1)
        
    last = length%(len(bounds)-1)+200-edge_width
    BKG_final = np.append(BKG_final,BKG[-1][:,last:],axis=1)

    sorted_index = BKG_final[0].argsort()
    BKG_final = np.array([np.take_along_axis(BKG_final[0], sorted_index, axis=0),np.take_along_axis(BKG_final[1], sorted_index, axis=0)]) 

    BKG_final[1]=savgol_filter(BKG_final[1],L_n,2)
    BKG_final[1]=savgol_filter(BKG_final[1],L_n*2+1,2)
    BKG_final[1]=savgol_filter(BKG_final[1],L_n*3,2)

    #si puo fare sicuramente piu pulito
    BKG_final = np.array([np.unique(BKG_final[0]), np.interp(np.unique(BKG_final[0]), BKG_final[0], BKG_final[1])])
    
    if plot==True:
        plt.plot(BKG_final[0],BKG_final[1],label='Estimated background')
        plt.legend()

    return BKG_final

# %%
col= 'r4c3'
#'r5c7'  
#'r5c2' bello
#'r1c3' brutto ma comunque dai
S =np.array(data[['wn',col]].copy()).transpose()
S=interpol(S)
S=S
BKG=bkg_full_fit(S, p=10, edge_width=50, edge_weight=2, L_n=41, plot=True)

raman_plot()
plt.plot(S[0],S[1]-BKG[1])

# %% [markdown]
# # Gaussian Kernel

# %%
col= 'r1c5'  #'r5c2'
S =np.array(data[['wn',col]].copy()).transpose()
raman_plot()
plt.plot(S[0],S[1], label = 'original')
S=interpol(S)
plt.plot(S[0],S[1], label = 'interpolated')
plt.title('Spectrum on which to test the analysis',fontsize=18,fontweight='bold')
plt.legend()
#############################################################################################
L_n=41                                      #lenght of smoothing filter for noise removal  #                                                                                 #
#############################################################################################
S_smooth = S.copy()
S_smooth[1]=savgol_filter(S[1],L_n,1)

plt.figure(figsize=(16,6))
plt.xlabel("sample",fontsize=18)
plt.ylabel("Intensity [some unit]",fontsize=18)
plt.title('Noise-removed spectrum via Savitzky–Golay filter with span $L_n$ and a second order pol',fontsize=18,fontweight='bold')
plt.plot(S[0],S[1], label='original signal')
plt.plot(S_smooth[0],S_smooth[1], label='smoothed signal')
plt.legend()

# %%
# GENERATIVE FUNCTION
p= 150   # polinomial order
Sigma = 150
edge_width = 5 # this is for the edge problem of polinomial fitting
edge_weight = 10

#############################################################
# vector/matrice Y and X
Y = S_smooth[1]
x = S_smooth[0]
sigma = Sigma/(x[-1]-x[0])
x = (x-x[0])/(x[-1]-x[0])
X = np.zeros((len(x),p))

for i in enumerate(np.linspace(0-sigma,1+sigma,p)):
   X[:, i[0]] = (np.exp(-(x-i[1])**(2)/(2*sigma**2)))

# vector C
H = np.concatenate((np.ones(edge_width)*edge_weight, np.ones(X.shape[0]-2*edge_width), np.ones(edge_width)*edge_weight))
C = - np.dot(H,X)

# solving the linear programming problem
res = linprog(C, A_ub=X, b_ub = Y,bounds = (0, None), method='highs-ds')
W = res['x']
print('sum(Y-XW) = ', res['fun'])
print('status = ', res['status'])
print('message = ', res['message'])
print('# of iter = ', res['nit'])

# generate the BKG
BKG = np.dot(X,W)
raman_plot()
plt.plot(S[0], BKG)
plt.plot(S[0],S[1])
plt.plot(S_smooth[0],S_smooth[1])
XX = np.arange(200,1000)

plt.plot(XX, S[1,100]/2*(np.exp(-(XX-600)**(2)/(2*Sigma**2))),label='Kernel function')
# SUBTRACTION
raman_plot()
plt.plot(S[0],S[1]-BKG)
# Out:
# sum(Y-XW) =  -1543459.9322616276
# status =  0
# message =  Optimization terminated successfully.
# # of iter =  425

# %%
S_smooth[0,-1]
# Out:
# 4002.0

# %%
# GENERATIVE FUNCTION
p= 200   # polinomial order
sigma = 150
edge_width = 5 # this is for the edge problem of polinomial fitting
edge_weight = 10

#############################################################
# matrice X
X = np.zeros((len(S_smooth[0]),p))

for i in enumerate(np.linspace(S_smooth[0,0]-sigma,S_smooth[0,-1]+sigma,p)):
   X[:, i[0]] = (np.exp(-(S_smooth[0]-i[1])**(2)/(2*sigma**2)))

# vector C
H = np.concatenate((np.ones(edge_width)*edge_weight, np.ones(X.shape[0]-2*edge_width), np.ones(edge_width)*edge_weight))
C = - np.dot(H,X)

# solving the linear programming problem
res = linprog(C, A_ub=X, b_ub = S_smooth[1],bounds = (0, None), method='highs-ds')
W = res['x']
print('sum(Y-XW) = ', res['fun'])
print('status = ', res['status'])
print('message = ', res['message'])
print('# of iter = ', res['nit'])

# generate the BKG
BKG = np.dot(X,W)
raman_plot()
plt.plot(S[0], BKG)
plt.plot(S[0],S[1])
plt.plot(S_smooth[0],S_smooth[1])
XX = np.arange(200,1000)

plt.plot(XX, S[1,100]/2*(np.exp(-(XX-600)**(2)/(2*Sigma**2))),label='Kernel function')
# SUBTRACTION
raman_plot()
plt.plot(S[0],S[1]-BKG)
# Out:
# sum(Y-XW) =  -1543464.2214732245
# status =  0
# message =  Optimization terminated successfully.
# # of iter =  524

# %%
plt.plot(W)

# %% [markdown]
# ## Write the above as a function

# %%
# GENERATIVE FUNCTION
p= 1000   # number of gaussians in the range

sigma = 200
edge_width = 5 # this is for the edge problem of polinomial fitting
edge_weight = 1

def bkg_via_gauss(S, L_n, sigma, edge_width=5, edge_weight=2, plot=False):
   
   # smoothing
   S_smooth = S.copy()
   S_smooth[1]=savgol_filter(S[1],L_n,2)

   # vector/matrice Y and X
   Y = S_smooth[1]
   x = S_smooth[0]
   s = sigma/(x[-1]-x[0])
   x = (x-x[0])/(x[-1]-x[0])
   X = np.zeros((len(x),p))
   for i in enumerate(np.linspace(0-2*s,1+2*s,p)):
      X[:, i[0]] = (np.exp(-(x-i[1])**(2)/(2*s**2))) #generative function

   # vector C
   H = np.concatenate((np.ones(edge_width)*edge_weight, np.ones(X.shape[0]-2*edge_width), np.ones(edge_width)*edge_weight))
   C = - np.dot(H,X)

   # solving the linear programming problem
   res = linprog(C, A_ub=X, b_ub = Y,bounds = (0, None), method='highs-ds')
   W = res['x']
   status = res['status'] # status = 0 means OK
   print('sum(Y-XW) = ', res['fun'])
   print('message = ', res['message'])
   print('# of iter = ', res['nit'])

   if status!=0:
      print('Fit failed !!!')
      return
   # generate the BKG

   BKG = np.array([S_smooth[0], np.dot(X,W)])
   S_nobkg = S.copy()
   S_nobkg[1] -= BKG[1]

   if plot==True:
      _raman_labels()
      plt.plot(BKG[0],BKG[1], label='Estimated background')
      plt.plot(S[0],S[1], label='Original signal')
      plt.plot(S_smooth[0],S_smooth[1], label='Smoothed signal')
      XX = np.arange(200,1000)
      plt.plot(XX, S[1,100]/2*(np.exp(-(XX-600)**(2)/(2*sigma**2))),label='Kernel function')
      plt.legend()
      plt.show()
   return S_nobkg, BKG

# %%
col= 'r2c5' #'r3c9'  #'r5c2'
S = np.array(data[['wn',col]].copy()).transpose()
S = interpol(S)

S_nobkg, BKG = bkg_via_gauss(S,41,100,plot=True)
_raman_labels()
plt.plot(S_nobkg[0],S_nobkg[1])

# %% [markdown]
# # TEST

# %%
S_nobkg150, BKG150 = bkg_via_gauss(S,3,150)
S_nobkg100, BKG100 = bkg_via_gauss(S,3,100)
S_nobkg200, BKG200 = bkg_via_gauss(S,3,200)
_raman_labels()
plt.plot(S[0],S[1])
plt.plot(BKG150[0],BKG150[1], label='150')
plt.plot(BKG200[0],BKG200[1], label='200')
plt.plot(BKG100[0],BKG100[1], label='100')
plt.legend()
# Out:
# sum(Y-XW) =  -2133068.6737383613
# message =  Optimization terminated successfully.
# # of iter =  1897
# sum(Y-XW) =  -2138643.1938715726
# message =  Optimization terminated successfully.
# # of iter =  1440
# sum(Y-XW) =  -2129823.0361520266
# message =  Optimization terminated successfully.
# # of iter =  1808

# %% [markdown]
# # Let's see lots of samples

# %%
plt.figure(figsize=(10,5))
plt.xlabel(r'Raman shift [$cm^{-1}$]')
plt.ylabel('Counts')

for i in range(11):
    for j in range(11):
        col= 'r'+str(i+1)+'c'+str(j+1)
        S = np.array(data[['wn',col]].copy()).transpose()
        S = interpol(S)

        S_nobkg, BKG = bkg_via_gauss(S,41,100,plot=False)

        for k in range(len(S_nobkg[1])):
            if S_nobkg[1][k]<0:
                S_nobkg[1][k]=0

        plt.plot(S_nobkg[0],S_nobkg[1])
        #plt.xlim(0,1700)
# Out:
# sum(Y-XW) =  -561676.7217019637
# message =  Optimization terminated successfully.
# # of iter =  1731
# sum(Y-XW) =  -1478119.3373989526
# message =  Optimization terminated successfully.
# # of iter =  1965
# sum(Y-XW) =  -578504.4400226652
# message =  Optimization terminated successfully.
# # of iter =  1805
# sum(Y-XW) =  -640586.8076023153
# message =  Optimization terminated successfully.
# # of iter =  1474
# sum(Y-XW) =  -1520329.7822075598
# message =  Optimization terminated successfully.
# # of iter =  1843
# sum(Y-XW) =  -631456.9052737098
# message =  Optimization terminated successfully.
# # of iter =  2317
# sum(Y-XW) =  -896335.8837012368
# message =  Optimization terminated successfully.
# # of iter =  1832
# sum(Y-XW) =  -552917.5460987429
# message =  Optimization terminated successfully.
# # of iter =  1995
# sum(Y-XW) =  -753478.4372507136
# message =  Optimization terminated successfully.
# # of iter =  1632
# sum(Y-XW) =  -441137.448141343
# message =  Optimization terminated successfully.
# # of iter =  1955
# sum(Y-XW) =  -681240.0603245515
# message =  Optimization terminated successfully.
# # of iter =  2114
# sum(Y-XW) =  -657043.6357166588
# message =  Optimization terminated successfully.
# # of iter =  1676
# sum(Y-XW) =  -805386.6613045074
# message =  Optimization terminated successfully.
# # of iter =  1865
# sum(Y-XW) =  -654326.0493568592
# message =  Optimization terminated successfully.
# # of iter =  1607
# sum(Y-XW) =  -937777.9700503853
# message =  Optimization terminated successfully.
# # of iter =  1762
# sum(Y-XW) =  -2148926.964993694
# message =  Optimization terminated successfully.
# # of iter =  1558
# sum(Y-XW) =  -423830.5174122168
# message =  Optimization terminated successfully.
# # of iter =  1925
# sum(Y-XW) =  -989019.1347198831
# message =  Optimization terminated successfully.
# # of iter =  1781
# sum(Y-XW) =  -538438.137099099
# message =  Optimization terminated successfully.
# # of iter =  1713
# sum(Y-XW) =  -666131.0589808465
# message =  Optimization terminated successfully.
# # of iter =  2245
# sum(Y-XW) =  -436903.45535102667
# message =  Optimization terminated successfully.
# # of iter =  1700
# sum(Y-XW) =  -1090075.8477652848
# message =  Optimization terminated successfully.
# # of iter =  1479
# sum(Y-XW) =  -384227.16924085387
# message =  Optimization terminated successfully.
# # of iter =  1499
# sum(Y-XW) =  -971466.1188724168
# message =  Optimization terminated successfully.
# # of iter =  1983
# sum(Y-XW) =  -604191.4643883216
# message =  Optimization terminated successfully.
# # of iter =  1558
# sum(Y-XW) =  -632370.3910921733
# message =  Optimization terminated successfully.
# # of iter =  1801
# sum(Y-XW) =  -1560690.175556027
# message =  Optimization terminated successfully.
# # of iter =  2154
# sum(Y-XW) =  -609032.7190280018
# message =  Optimization terminated successfully.
# # of iter =  1678
# sum(Y-XW) =  -2145993.1303906613
# message =  Optimization terminated successfully.
# # of iter =  1707
# sum(Y-XW) =  -664513.6963016369
# message =  Optimization terminated successfully.
# # of iter =  1804
# sum(Y-XW) =  -461250.4821138697
# message =  Optimization terminated successfully.
# # of iter =  1818
# sum(Y-XW) =  -906220.6469360865
# message =  Optimization terminated successfully.
# # of iter =  1670
# sum(Y-XW) =  -13429568.445665896
# message =  Optimization terminated successfully.
# # of iter =  1703
# sum(Y-XW) =  -485681.9327690916
# message =  Optimization terminated successfully.
# # of iter =  1396
# sum(Y-XW) =  -7069688.666673664
# message =  Optimization terminated successfully.
# # of iter =  1926
# sum(Y-XW) =  -1070945.6432584377
# message =  Optimization terminated successfully.
# # of iter =  1935
# sum(Y-XW) =  -489712.8181933779
# message =  Optimization terminated successfully.
# # of iter =  1555
# sum(Y-XW) =  -540037.1204507187
# message =  Optimization terminated successfully.
# # of iter =  1518
# sum(Y-XW) =  -756367.524568027
# message =  Optimization terminated successfully.
# # of iter =  1500
# sum(Y-XW) =  -479646.87601886416
# message =  Optimization terminated successfully.
# # of iter =  1400
# sum(Y-XW) =  -494404.3863711981
# message =  Optimization terminated successfully.
# # of iter =  1472
# sum(Y-XW) =  -4989661.528012127
# message =  Optimization terminated successfully.
# # of iter =  1796
# sum(Y-XW) =  -556922.0056624667
# message =  Optimization terminated successfully.
# # of iter =  1855
# sum(Y-XW) =  -759054.0424526411
# message =  Optimization terminated successfully.
# # of iter =  1573
# sum(Y-XW) =  -1095680.141972082
# message =  Optimization terminated successfully.
# # of iter =  1829
# Small |pivot| = 3.62756e-11 when nwork = 0
# sum(Y-XW) =  -8918443.50801439
# message =  Optimization terminated successfully.
# # of iter =  1046
# sum(Y-XW) =  -1318081.274936592
# message =  Optimization terminated successfully.
# # of iter =  1692
# sum(Y-XW) =  -10092704.21547856
# message =  Optimization terminated successfully.
# # of iter =  1572
# sum(Y-XW) =  -774169.6169892722
# message =  Optimization terminated successfully.
# # of iter =  1432
# sum(Y-XW) =  -685126.1528533257
# message =  Optimization terminated successfully.
# # of iter =  1602
# sum(Y-XW) =  -977022.561048984
# message =  Optimization terminated successfully.
# # of iter =  1858
# sum(Y-XW) =  -759127.498675651
# message =  Optimization terminated successfully.
# # of iter =  1718
# sum(Y-XW) =  -1670015.7274660282
# message =  Optimization terminated successfully.
# # of iter =  1844
# sum(Y-XW) =  -666091.156008962
# message =  Optimization terminated successfully.
# # of iter =  1995
# sum(Y-XW) =  -452314.7461847201
# message =  Optimization terminated successfully.
# # of iter =  1812
# sum(Y-XW) =  -982064.0692840545
# message =  Optimization terminated successfully.
# # of iter =  1475
# sum(Y-XW) =  -945058.9565321712
# message =  Optimization terminated successfully.
# # of iter =  1992
# sum(Y-XW) =  -1331943.5481552824
# message =  Optimization terminated successfully.
# # of iter =  1810
# sum(Y-XW) =  -532927.3866574296
# message =  Optimization terminated successfully.
# # of iter =  1687
# sum(Y-XW) =  -552224.8429721567
# message =  Optimization terminated successfully.
# # of iter =  1804
# sum(Y-XW) =  -648728.5631721822
# message =  Optimization terminated successfully.
# # of iter =  2075
# sum(Y-XW) =  -632796.4304198923
# message =  Optimization terminated successfully.
# # of iter =  1969
# sum(Y-XW) =  -1366850.2561704663
# message =  Optimization terminated successfully.
# # of iter =  1719
# sum(Y-XW) =  -711610.3300061872
# message =  Optimization terminated successfully.
# # of iter =  1681
# sum(Y-XW) =  -413406.1938825777
# message =  Optimization terminated successfully.
# # of iter =  1852
# sum(Y-XW) =  -1150110.1093966612
# message =  Optimization terminated successfully.
# # of iter =  1689
# sum(Y-XW) =  -1202278.225964018
# message =  Optimization terminated successfully.
# # of iter =  1941
# sum(Y-XW) =  -1122754.2088792578
# message =  Optimization terminated successfully.
# # of iter =  1537
# sum(Y-XW) =  -598008.7501728646
# message =  Optimization terminated successfully.
# # of iter =  1736
# sum(Y-XW) =  -807494.5458074545
# message =  Optimization terminated successfully.
# # of iter =  1768
# sum(Y-XW) =  -407776.87634995586
# message =  Optimization terminated successfully.
# # of iter =  1418
# sum(Y-XW) =  -1338244.6566312553
# message =  Optimization terminated successfully.
# # of iter =  1677
# sum(Y-XW) =  -436245.25659142365
# message =  Optimization terminated successfully.
# # of iter =  1414
# sum(Y-XW) =  -501275.7867645265
# message =  Optimization terminated successfully.
# # of iter =  2070
# sum(Y-XW) =  -1196056.9786495848
# message =  Optimization terminated successfully.
# # of iter =  2241
# sum(Y-XW) =  -1194047.7786526738
# message =  Optimization terminated successfully.
# # of iter =  2169
# sum(Y-XW) =  -1438808.4405541283
# message =  Optimization terminated successfully.
# # of iter =  1331
# sum(Y-XW) =  -513417.9248375591
# message =  Optimization terminated successfully.
# # of iter =  1739
# sum(Y-XW) =  -603502.7781257551
# message =  Optimization terminated successfully.
# # of iter =  1499
# sum(Y-XW) =  -512541.9941815594
# message =  Optimization terminated successfully.
# # of iter =  1564
# sum(Y-XW) =  -596485.3627564237
# message =  Optimization terminated successfully.
# # of iter =  1710
# sum(Y-XW) =  -1808580.7673875482
# message =  Optimization terminated successfully.
# # of iter =  1415
# sum(Y-XW) =  -821866.4186503274
# message =  Optimization terminated successfully.
# # of iter =  1713
# sum(Y-XW) =  -560880.137948333
# message =  Optimization terminated successfully.
# # of iter =  1864
# sum(Y-XW) =  -2049044.0479382675
# message =  Optimization terminated successfully.
# # of iter =  1797
# sum(Y-XW) =  -993311.0435523394
# message =  Optimization terminated successfully.
# # of iter =  1640
# sum(Y-XW) =  -1864625.099026289
# message =  Optimization terminated successfully.
# # of iter =  2097
# sum(Y-XW) =  -4819798.729710357
# message =  Optimization terminated successfully.
# # of iter =  2025
# sum(Y-XW) =  -506443.0399675844
# message =  Optimization terminated successfully.
# # of iter =  1625
# sum(Y-XW) =  -2004138.7366643776
# message =  Optimization terminated successfully.
# # of iter =  1678
# sum(Y-XW) =  -708237.3723458042
# message =  Optimization terminated successfully.
# # of iter =  2121
# sum(Y-XW) =  -1357083.7464744356
# message =  Optimization terminated successfully.
# # of iter =  1808
# sum(Y-XW) =  -3147271.701321364
# message =  Optimization terminated successfully.
# # of iter =  2077
# sum(Y-XW) =  -973539.5503753588
# message =  Optimization terminated successfully.
# # of iter =  1629
# sum(Y-XW) =  -741425.0403104175
# message =  Optimization terminated successfully.
# # of iter =  1989
# sum(Y-XW) =  -1244026.7109806468
# message =  Optimization terminated successfully.
# # of iter =  1781
# sum(Y-XW) =  -736970.3854292745
# message =  Optimization terminated successfully.
# # of iter =  1616
# sum(Y-XW) =  -1317263.9581078673
# message =  Optimization terminated successfully.
# # of iter =  1974
# sum(Y-XW) =  -1510753.0296684091
# message =  Optimization terminated successfully.
# # of iter =  1975
# sum(Y-XW) =  -872447.562447866
# message =  Optimization terminated successfully.
# # of iter =  1698
# sum(Y-XW) =  -797251.7260751594
# message =  Optimization terminated successfully.
# # of iter =  2072
# sum(Y-XW) =  -923579.4219275601
# message =  Optimization terminated successfully.
# # of iter =  2059
# sum(Y-XW) =  -1504685.8513606125
# message =  Optimization terminated successfully.
# # of iter =  2208
# sum(Y-XW) =  -942812.7713849413
# message =  Optimization terminated successfully.
# # of iter =  1734
# sum(Y-XW) =  -4736826.216721955
# message =  Optimization terminated successfully.
# # of iter =  1585
# sum(Y-XW) =  -2590443.661747524
# message =  Optimization terminated successfully.
# # of iter =  1669
# sum(Y-XW) =  -541845.8017340259
# message =  Optimization terminated successfully.
# # of iter =  1562
# sum(Y-XW) =  -517535.3532319037
# message =  Optimization terminated successfully.
# # of iter =  1998
# sum(Y-XW) =  -544661.6386506347
# message =  Optimization terminated successfully.
# # of iter =  1442
# sum(Y-XW) =  -2365453.9024202125
# message =  Optimization terminated successfully.
# # of iter =  1759
# sum(Y-XW) =  -393001.2081767845
# message =  Optimization terminated successfully.
# # of iter =  1601
# sum(Y-XW) =  -562788.2563955055
# message =  Optimization terminated successfully.
# # of iter =  1612
# sum(Y-XW) =  -1844557.9290454367
# message =  Optimization terminated successfully.
# # of iter =  1964
# sum(Y-XW) =  -794111.571879992
# message =  Optimization terminated successfully.
# # of iter =  1517
# sum(Y-XW) =  -794641.302843922
# message =  Optimization terminated successfully.
# # of iter =  1725
# sum(Y-XW) =  -654320.4281347385
# message =  Optimization terminated successfully.
# # of iter =  1545
# sum(Y-XW) =  -1183634.0426287802
# message =  Optimization terminated successfully.
# # of iter =  1196
# sum(Y-XW) =  -2385846.482940307
# message =  Optimization terminated successfully.
# # of iter =  1475
# sum(Y-XW) =  -2846088.4880904825
# message =  Optimization terminated successfully.
# # of iter =  1613
# sum(Y-XW) =  -14254443.214466069
# message =  Optimization terminated successfully.
# # of iter =  1747
# sum(Y-XW) =  -427003.3611817607
# message =  Optimization terminated successfully.
# # of iter =  1720
